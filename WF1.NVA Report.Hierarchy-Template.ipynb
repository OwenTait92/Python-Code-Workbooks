# %%
from seeq import spy #imports the spy connector to allow the connection to Seeq
import pandas as pd
from seeq.spy.assets import Asset
#To automatically run all lines of code, hit the "restart the kernel, then re-run the whole notebook (with dialog)" button (double right arrow)

# %% [markdown]
# # 1. Generate Workbook and Search Path

# %%
workbook_name = 'Brintnell NVA Report'#Edit Required-> change name to desired Seeq Workbook to access
signal_search_name = 'Liquid Flow Rate'#Edit Required-> enter the 1st signal required in your formula
search_path = 'Brintnell / Pelican Wells >> Producers >> * >> * >> *'# Edit Required-> Adjust based on Producers or Injector path you want the code to reference. * means ALL Assets in the corresponding hierarchy level

# %%
rate_result_df= spy.search(
    {"Name": signal_search_name, 
     "Path": search_path
    }, quiet = True).drop_duplicates(subset = ["Asset"], keep = "first")
#search all Producers (or Injectors if changed to "Injectors") in area for the signal Liquid Flow rate (signal_search_name)

# %%
def signal_search_check(search_result_df, signal_check_name):
    search_assets = search_result_df['Asset'].tolist()
    search_path = search_result_df['Path'].tolist()
    #Make a list of the asset & paths found for initail searched signals (signal_search_name)
    
    search_dict = {'Asset': search_assets} #generates a dictionary of all the Assets in search_results
    search_check_df = pd.DataFrame(search_dict)
    search_check_df['Name'] = '/^' + signal_check_name + '$/'
    search_check_df['Path'] = search_path
    return spy.search(search_check_df, quiet = True).drop_duplicates(subset = ["Asset"], keep = "first")
    #Search the list from "Liquid FLow Rates" signals and removes any duplicates (this step assists if there are multiple signals generated in the hiearchy due to an upload error, keeps the first signal only)

# %% [markdown]
# # 2. Create signal searches

# %%
rod_search_df = signal_search_check(search_result_df = rate_result_df , signal_check_name = 'Rod Speed')#Edit Required-> change the signal_check_name to the signal name required in your code. Update rod_search_df to the unique name required for your code
torque_search_df = signal_search_check(search_result_df = rate_result_df , signal_check_name = 'Torque')#Edit Required-> change the signal_check_name to the signal name required in your code. Update torque_search_df to the unique name required for your code
eff_search_df = signal_search_check(search_result_df = rate_result_df , signal_check_name = 'SAM_PMP_EFF')#Edit Required-> change the signal_check_name to the signal name required in your code. Update eff_search_df to the unique name required for your code

#need to list all of your signals here. Either Add/Delete rows if additional/fewer signals are required, respectively
#The signal_name_check 'variable' should be the exact name pulled from your Seeq workbook (ie. Rod Speed,JTF, Polymer Injection Rate etc.)

# %% [markdown]
# # 3. Create 1 Main Report

# %%
meta_data_df = rate_result_df.append(rod_search_df, ignore_index = True)#Edit Required-> update the "*_search_df" changed in Step #2
meta_data_df = meta_data_df.append(torque_search_df, ignore_index = True)#Edit Required-> update the "*_search_df" changed in Step #2
meta_data_df = meta_data_df.append(eff_search_df, ignore_index = True)#Edit Required-> update the "*_search_df" changed in Step #2
meta_data_df =  meta_data_df.assign(Field = meta_data_df['Path'].str.split(">>").str[2].str.strip())
meta_data_df =  meta_data_df.assign(Pad = meta_data_df['Path'].str.split(">>").str[3].str.strip())
meta_data_df['Build Path'] = 'NVA Variance Report'#Edit Required-> change 'NVA Variance Report' to desired Path Name for your code (this will be linked to WF2.)
meta_data_df['Build Asset'] = meta_data_df['Field']
#This step merges each individual signal report into 1 main report

# %%
meta_data_df
#displays the main report
# Out:
#                                         ID  \
# 0     994C3934-A22F-4043-8D1B-55AB611DD659
# 1     E558CF28-C46B-42AA-AA36-9DDC51D7E1C9
# 2     E6E99BDE-03F7-4897-8C60-1E462D423E8F
# 3     2230B928-BC4F-4CAE-87E3-9E8DE2BD003E
# 4     168B79BC-863F-4D7C-A312-F611E8365B4A
# ...                                    ...
# 4212  C15EAF3D-7449-49BC-8858-F8FE551C3EFB
# 4213  29D7DF8F-874C-4FBE-A9B5-B3C73D3C7946
# 4214  81E3BE1D-4044-41CA-BD39-8B81EF881862
# 4215  7F179B90-9753-4849-9395-78395CD59D2A
# 4216  CDC47B4A-FB40-4BB8-8C46-A363BEABC733
#
#                                                    Path                Asset  \
# 0     Brintnell / Pelican Wells >> Producers >> Cent...   100/13-20-081-22W4
# 1     Brintnell / Pelican Wells >> Producers >> Cent...  103/05A-21-081-22W4
# 2     Brintnell / Pelican Wells >> Producers >> Cent...  104/09D-20-081-22W4
# 3     Brintnell / Pelican Wells >> Producers >> Cent...  102/12D-08-081-22W4
# 4     Brintnell / Pelican Wells >> Producers >> Cent...  102/13C-08-081-22W4
# ...                                                 ...                  ...
# 4212  Brintnell / Pelican Wells >> Producers >> Sout...  103/16D-07-081-22W4
# 4213  Brintnell / Pelican Wells >> Producers >> Sout...   100/03-32-080-22W4
# 4214  Brintnell / Pelican Wells >> Producers >> Sout...   100/01-15-081-23W4
# 4215  Brintnell / Pelican Wells >> Producers >> Sout...  100/11D-01-081-23W4
# 4216  Brintnell / Pelican Wells >> Producers >> Sout...  100/15C-01-081-23W4
#
#                   Name                                Description  \
# 0     Liquid Flow Rate   BP01 100/13-20-081-22W4 Liquid Flow Rate
# 1     Liquid Flow Rate  BP02 103/05A-21-081-22W4 Liquid Flow Rate
# 2     Liquid Flow Rate  BP02 104/09D-20-081-22W4 Liquid Flow Rate
# 3     Liquid Flow Rate  BP03 102/12D-08-081-22W4 Liquid Flow Rate
# 4     Liquid Flow Rate  BP03 102/13C-08-081-22W4 Liquid Flow Rate
# ...                ...                                        ...
# 4212       SAM_PMP_EFF       WB42 103/16D-07-081-22W4 SAM_PMP_EFF
# 4213       SAM_PMP_EFF        WB43 100/03-32-080-22W4 SAM_PMP_EFF
# 4214       SAM_PMP_EFF        WB46 100/01-15-081-23W4 SAM_PMP_EFF
# 4215       SAM_PMP_EFF       WB46 100/11D-01-081-23W4 SAM_PMP_EFF
# 4216       SAM_PMP_EFF       WB46 100/15C-01-081-23W4 SAM_PMP_EFF
#
#                   Type Value Unit Of Measure Datasource Name  Archived  \
# 0     CalculatedSignal                   NaN  Well Structure     False
# 1     CalculatedSignal                   NaN  Well Structure     False
# 2     CalculatedSignal                   NaN  Well Structure     False
# 3     CalculatedSignal                   NaN  Well Structure     False
# 4     CalculatedSignal                   NaN  Well Structure     False
# ...                ...                   ...             ...       ...
# 4212  CalculatedSignal                   NaN  Well Structure     False
# 4213  CalculatedSignal                   NaN  Well Structure     False
# 4214  CalculatedSignal                   NaN  Well Structure     False
# 4215  CalculatedSignal                   NaN  Well Structure     False
# 4216  CalculatedSignal                   NaN  Well Structure     False
#
#                   Field   Pad           Build Path        Build Asset
# 0     Central Brintnell  BP01  NVA Variance Report  Central Brintnell
# 1     Central Brintnell  BP02  NVA Variance Report  Central Brintnell
# 2     Central Brintnell  BP02  NVA Variance Report  Central Brintnell
# 3     Central Brintnell  BP03  NVA Variance Report  Central Brintnell
# 4     Central Brintnell  BP03  NVA Variance Report  Central Brintnell
# ...                 ...   ...                  ...                ...
# 4212    South Brintnell  WB42  NVA Variance Report    South Brintnell
# 4213    South Brintnell  WB43  NVA Variance Report    South Brintnell
# 4214    South Brintnell  WB46  NVA Variance Report    South Brintnell
# 4215    South Brintnell  WB46  NVA Variance Report    South Brintnell
# 4216    South Brintnell  WB46  NVA Variance Report    South Brintnell
#
# [4217 rows x 13 columns]

# %% [markdown]
# # 4. Create Formulas for workflow

# %%
#Copy/Paste all formulas from your Seeq Workbook (Seeq Workbook-> Variable-> Item Properties-> Formula)
#Assign a name to the formula (ie. variance_formula=...)
variance_formula = """
$twohr_formula= $d.movingAverageFilter(30min,2hr)
$twentyfourhr_formula= $d.movingAverageFilter(30min,24hr)
$frcond_20 = ((($twohr_formula-$twentyfourhr_formula)/$twentyfourhr_formula)*100).setUnits('%')
$frcond_20
"""

mvg_avg_formula = """
$frcond_20 = $v.movingAverageFilter(30min,2hr)
$frcond_20
"""

# %% [markdown]
# # 5. Create Defintions

# %%
#definition or recipe for custom hierarchy
class Report(Asset):
    @Asset.Component()
    def Pads(self, metadata):
        return self.build_components(template = Pad, metadata = metadata, column_name = 'Pad')
                                     
class Pad(Asset):
    @Asset.Component()
    def Wells(self, metadata):
        return self.build_components(template = Well, metadata = metadata, column_name = 'Asset') 

class Well(Asset):
    @Asset.Attribute()
    def Liquid_Flow_Rate(self, metadata):#Edit Required-> Adjust name as required (ie. Liquid_Flow_Rate)
        return metadata[metadata['Name'].str.match('Liquid Flow Rate')]#Edit Required-> enter signal_search_name from Step #1

    @Asset.Attribute()
    def Flow_Rate_Variance(self, metadata):#Edit Required-> Adjust name as required (ie. Flow_Rate_Variance)
        return {
            'Type': 'Signal', #Edit Required-> Keep as Signal if it's a variable, change to condition if using a Tool Condition
            'Formula': variance_formula, #Edit Required-> Update to name for the formula used in Step #4
            'Formula Parameters': {
                '$d': self.Liquid_Flow_Rate(metadata)   #Edit Required-> ensure the $letter is same as Step #4            
            }           
            
        }

#Repeat the @ Liquid_Flow_Rate edits (just above) for the below def based on the signals/formulas your wanted to generate
    
    @Asset.Attribute()
    def Torque(self, metadata):
        return metadata[metadata['Name'].str.match('Torque')]

    @Asset.Attribute()
    def Torque_Variance(self, metadata):
        return {
            'Type': 'Signal',
            'Formula': variance_formula,
            'Formula Parameters': {
                '$d': self.Torque(metadata)                
            }           
            
        }
    @Asset.Attribute()
    def Pump_Eff(self, metadata):
        return metadata[metadata['Name'].str.match('SAM_PMP_EFF')]

    @Asset.Attribute()
    def Pump_Eff_Variance(self, metadata):
        return {
            'Type': 'Signal',
            'Formula': variance_formula,
            'Formula Parameters': {
                '$d': self.Pump_Eff(metadata)                
            }           
            
        }
    @Asset.Attribute()
    def Rod_Speed(self, metadata):
        return metadata[metadata['Name'].str.match('Rod Speed')]

    @Asset.Attribute()
    def Rod_Speed_Smoothed(self, metadata):
        return {
            'Type': 'Signal',
            'Formula': mvg_avg_formula,
            'Formula Parameters': {
                '$v': self.Rod_Speed(metadata)                
            }           
            
        }

# %%
#build asset tree from "Report" definition
build_df = spy.assets.build(Report, meta_data_df)

# %%
#remove assets with no type i.e wells without SAM_PUMP_EFF signal will be excluded
build_df = build_df[build_df['Type'].notna()].reset_index()

# %%
#check Build Result for unsucessful rows
build_df[build_df['Build Result'] != 'Success'][['Type', 'Asset', 'Path', 'Build Result']]
# Out:
# Empty DataFrame
# Columns: [Type, Asset, Path, Build Result]
# Index: []

# %%
build_df[['ID','Type','Asset', 'Name', 'Build Result','Path', 'Asset Object', 'Template']]
#builds the report (items) that will be presented in your report
# Out:
#                                          ID              Type  \
# 0                                       NaN            Signal
# 1      994C3934-A22F-4043-8D1B-55AB611DD659  CalculatedSignal
# 2      E616551E-394E-43C2-80C5-01191B3EB7DD  CalculatedSignal
# 3                                       NaN            Signal
# 4      7DDD1658-7212-47EC-8799-F32EA19909B1  CalculatedSignal
# ...                                     ...               ...
# 10573  1F9C5910-566C-4636-B044-B2C574747E54  CalculatedSignal
# 10574                                   NaN            Signal
# 10575                                   NaN             Asset
# 10576                                   NaN             Asset
# 10577                                   NaN             Asset
#
#                      Asset                 Name Build Result  \
# 0       100/13-20-081-22W4   Flow Rate Variance      Success
# 1       100/13-20-081-22W4     Liquid Flow Rate      Success
# 2       100/13-20-081-22W4             Pump Eff      Success
# 3       100/13-20-081-22W4    Pump Eff Variance      Success
# 4       100/13-20-081-22W4            Rod Speed      Success
# ...                    ...                  ...          ...
# 10573  100/15C-01-081-23W4               Torque      Success
# 10574  100/15C-01-081-23W4      Torque Variance      Success
# 10575  100/15C-01-081-23W4  100/15C-01-081-23W4      Success
# 10576                 WB46                 WB46      Success
# 10577      South Brintnell      South Brintnell      Success
#
#                                                    Path  \
# 0      NVA Variance Report >> Central Brintnell >> BP01
# 1      NVA Variance Report >> Central Brintnell >> BP01
# 2      NVA Variance Report >> Central Brintnell >> BP01
# 3      NVA Variance Report >> Central Brintnell >> BP01
# 4      NVA Variance Report >> Central Brintnell >> BP01
# ...                                                 ...
# 10573    NVA Variance Report >> South Brintnell >> WB46
# 10574    NVA Variance Report >> South Brintnell >> WB46
# 10575    NVA Variance Report >> South Brintnell >> WB46
# 10576            NVA Variance Report >> South Brintnell
# 10577                               NVA Variance Report
#
#                                             Asset Object Template
# 0      NVA Variance Report >> Central Brintnell >> BP...     Well
# 1      NVA Variance Report >> Central Brintnell >> BP...     Well
# 2      NVA Variance Report >> Central Brintnell >> BP...     Well
# 3      NVA Variance Report >> Central Brintnell >> BP...     Well
# 4      NVA Variance Report >> Central Brintnell >> BP...     Well
# ...                                                  ...      ...
# 10573  NVA Variance Report >> South Brintnell >> WB46...     Well
# 10574  NVA Variance Report >> South Brintnell >> WB46...     Well
# 10575  NVA Variance Report >> South Brintnell >> WB46...     Well
# 10576     NVA Variance Report >> South Brintnell >> WB46      Pad
# 10577             NVA Variance Report >> South Brintnell   Report
#
# [10578 rows x 8 columns]

# %%
#push asset tree to workbook defined by workbook_name variable assigned in Step #1
spy.push(metadata=build_df, workbook = workbook_name)
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pushed successfully to datasource <strong>Seeq Data Lab [Datasource ID: Seeq Data Lab]</strong> and scoped to workbook ID <strong>768B1C69-AF81-4C3F-8229-0EB774A5B716</strong><br>Click the following link to see what you pushed in Seeq:<br><a href="https://cnrl.seeq.site/C56CC991-6758-43F7-BB58-C10B7DCD64B3/workbook/768B1C69-AF81-4C3F-8229-0EB774A5B716/worksheet/EB5CE918-ED39-4137-B159-E89ABBB2A3A3" target="_new">https://cnrl.seeq.site/C56CC991-6758-43F7-BB58-C10B7DCD64B3/workbook/768B1C69-AF81-4C3F-8229-0EB774A5B716/worksheet/EB5CE918-ED39-4137-B159-E89ABBB2A3A3</a></div>
#        index              Type  \
# 0          0  CalculatedSignal
# 1          1  CalculatedSignal
# 2          2  CalculatedSignal
# 3          3  CalculatedSignal
# 4          4  CalculatedSignal
# ...      ...               ...
# 10573  11200  CalculatedSignal
# 10574  11201  CalculatedSignal
# 10575  11202             Asset
# 10576  11203             Asset
# 10577  11204             Asset
#
#                                                  Formula  \
# 0      \n$twohr_formula= $d.movingAverageFilter(30min...
# 1                                                    NaN
# 2                                                    NaN
# 3      \n$twohr_formula= $d.movingAverageFilter(30min...
# 4                                                    NaN
# ...                                                  ...
# 10573                                                NaN
# 10574  \n$twohr_formula= $d.movingAverageFilter(30min...
# 10575                                                NaN
# 10576                                                NaN
# 10577                                                NaN
#
#                                   Formula Parameters                 Name  \
# 0           [d=9A80864B-5933-4939-ACD7-2F0DA4CBE5B0]   Flow Rate Variance
# 1      [signal=994C3934-A22F-4043-8D1B-55AB611DD659]     Liquid Flow Rate
# 2      [signal=E616551E-394E-43C2-80C5-01191B3EB7DD]             Pump Eff
# 3           [d=33963A32-6E2C-4E6C-8DC4-D84727B5CB8C]    Pump Eff Variance
# 4      [signal=7DDD1658-7212-47EC-8799-F32EA19909B1]            Rod Speed
# ...                                              ...                  ...
# 10573  [signal=1F9C5910-566C-4636-B044-B2C574747E54]               Torque
# 10574       [d=A5E176A3-4A48-4E26-9E58-AE209B3E2943]      Torque Variance
# 10575                                            NaN  100/15C-01-081-23W4
# 10576                                            NaN                 WB46
# 10577                                            NaN      South Brintnell
#
#                      Asset                                       Asset Object  \
# 0       100/13-20-081-22W4  NVA Variance Report >> Central Brintnell >> BP...
# 1       100/13-20-081-22W4  NVA Variance Report >> Central Brintnell >> BP...
# 2       100/13-20-081-22W4  NVA Variance Report >> Central Brintnell >> BP...
# 3       100/13-20-081-22W4  NVA Variance Report >> Central Brintnell >> BP...
# 4       100/13-20-081-22W4  NVA Variance Report >> Central Brintnell >> BP...
# ...                    ...                                                ...
# 10573  100/15C-01-081-23W4  NVA Variance Report >> South Brintnell >> WB46...
# 10574  100/15C-01-081-23W4  NVA Variance Report >> South Brintnell >> WB46...
# 10575  100/15C-01-081-23W4  NVA Variance Report >> South Brintnell >> WB46...
# 10576                 WB46     NVA Variance Report >> South Brintnell >> WB46
# 10577      South Brintnell             NVA Variance Report >> South Brintnell
#
#                                                    Path Template Build Result  \
# 0      NVA Variance Report >> Central Brintnell >> BP01     Well      Success
# 1      NVA Variance Report >> Central Brintnell >> BP01     Well      Success
# 2      NVA Variance Report >> Central Brintnell >> BP01     Well      Success
# 3      NVA Variance Report >> Central Brintnell >> BP01     Well      Success
# 4      NVA Variance Report >> Central Brintnell >> BP01     Well      Success
# ...                                                 ...      ...          ...
# 10573    NVA Variance Report >> South Brintnell >> WB46     Well      Success
# 10574    NVA Variance Report >> South Brintnell >> WB46     Well      Success
# 10575    NVA Variance Report >> South Brintnell >> WB46     Well      Success
# 10576            NVA Variance Report >> South Brintnell      Pad      Success
# 10577                               NVA Variance Report   Report      Success
#
#        ...              Field   Pad   Referenced Name  \
# 0      ...                NaN   NaN               NaN
# 1      ...  Central Brintnell  BP01  Liquid Flow Rate
# 2      ...  Central Brintnell  BP01       SAM_PMP_EFF
# 3      ...                NaN   NaN               NaN
# 4      ...  Central Brintnell  BP01         Rod Speed
# ...    ...                ...   ...               ...
# 10573  ...    South Brintnell  WB46            Torque
# 10574  ...                NaN   NaN               NaN
# 10575  ...                NaN   NaN               NaN
# 10576  ...                NaN   NaN               NaN
# 10577  ...                NaN   NaN               NaN
#
#                                          Referenced Path     Referenced Asset  \
# 0                                                    NaN                  NaN
# 1      Brintnell / Pelican Wells >> Producers >> Cent...   100/13-20-081-22W4
# 2      Brintnell / Pelican Wells >> Producers >> Cent...   100/13-20-081-22W4
# 3                                                    NaN                  NaN
# 4      Brintnell / Pelican Wells >> Producers >> Cent...   100/13-20-081-22W4
# ...                                                  ...                  ...
# 10573  Brintnell / Pelican Wells >> Producers >> Sout...  100/15C-01-081-23W4
# 10574                                                NaN                  NaN
# 10575                                                NaN                  NaN
# 10576                                                NaN                  NaN
# 10577                                                NaN                  NaN
#
#       Reference Datasource Class  Datasource ID  \
# 0           NaN    Seeq Data Lab  Seeq Data Lab
# 1          True    Seeq Data Lab  Seeq Data Lab
# 2          True    Seeq Data Lab  Seeq Data Lab
# 3           NaN    Seeq Data Lab  Seeq Data Lab
# 4          True    Seeq Data Lab  Seeq Data Lab
# ...         ...              ...            ...
# 10573      True    Seeq Data Lab  Seeq Data Lab
# 10574       NaN    Seeq Data Lab  Seeq Data Lab
# 10575       NaN    Seeq Data Lab  Seeq Data Lab
# 10576       NaN    Seeq Data Lab  Seeq Data Lab
# 10577       NaN    Seeq Data Lab  Seeq Data Lab
#
#                                                  Data ID Push Result
# 0      [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 1      [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 2      [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 3      [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 4      [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# ...                                                  ...         ...
# 10573  [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 10574  [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Signal...     Success
# 10575  [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Asset}...     Success
# 10576  [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Asset}...     Success
# 10577  [768B1C69-AF81-4C3F-8229-0EB774A5B716] {Asset}...     Success
#
# [10578 rows x 25 columns]
